# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

# %%
def diff_data(path):
  data = pd.read_csv(path);
  # Apply logarithmic transformation
  data['log_close'] = np.log(data['Close'])
  # Calculate the first-order difference (residual) of the 'Close' prices
  data['log_close_diff'] = data['log_close'].diff()
  data = data.dropna()
  return data

# %%
# loading dataset
data = diff_data('./IBM.csv')

# %%
# plot original close price
plt.figure(figsize=(12, 6))
plt.plot(data['Close'], label='Original Close Price')
plt.title('Original Close Price Over Time')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# plot diff
plt.figure(figsize=(12, 6))
plt.plot(data['log_close_diff'], label='Residual of Close Price')
plt.title('Residual of Close Price Over Time')
plt.xlabel('Time')
plt.ylabel('Residual')
plt.legend()
plt.show()

# %%
def prepare_and_build_rnn_model(data, look_back=25):
    # Standardize the residuals
    scaler = StandardScaler()
    scaled_residual = scaler.fit_transform(data['log_close_diff'].values.reshape(-1, 1))

    # Function to create dataset
    def create_dataset(dataset, look_back):
        X, Y = [], []
        for i in range(len(dataset) - look_back - 1):
            a = dataset[i:(i + look_back), 0]
            X.append(a)
            Y.append(dataset[i + look_back, 0])
        return np.array(X), np.array(Y)

    # Split into training and testing sets
    train_size = int(len(scaled_residual) * 0.8)
    test_size = len(scaled_residual) - train_size
    train, test = scaled_residual[0:train_size,:], scaled_residual[train_size:len(scaled_residual),:]

    # Create training and testing data
    X_train, Y_train = create_dataset(train, look_back)
    X_test, Y_test = create_dataset(test, look_back)

    # Reshape input to be [samples, time steps, features]
    X_train = np.reshape(X_train, (X_train.shape[0], look_back, 1))
    X_test = np.reshape(X_test, (X_test.shape[0], look_back, 1))

    # Build the LSTM model with Dropout layers
    model = Sequential()
    model.add(LSTM(50, input_shape=(look_back, 1), return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')

    return model, X_train, Y_train, X_test, Y_test, scaler

# %%
def train_and_plot_loss(model, X_train, Y_train, epochs=200, batch_size=128):
    # Train the model and record the history
    history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=2)

    # Plotting the training loss
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.title('Training Loss per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    return model

# %%
model, X_train, Y_train, X_test, Y_test, scaler = prepare_and_build_rnn_model(data, look_back=50)

trained_model = train_and_plot_loss(model, X_train, Y_train, epochs=200, batch_size=64)
# Out:
# 2023-11-20 14:46:32.307150: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-20 14:46:32.309757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-20 14:46:32.310431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-11-20 14:46:32.419918: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-20 14:46:32.420569: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-20 14:46:32.421135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/200
# 2023-11-20 14:46:32.782560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-20 14:46:32.783891: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-20 14:46:32.784799: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-11-20 14:46:32.897858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-20 14:46:32.898647: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-20 14:46:32.899359: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-11-20 14:46:33.411989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-20 14:46:33.413204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-20 14:46:33.414087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-11-20 14:46:33.539975: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-20 14:46:33.540711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-20 14:46:33.541508: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 194/194 - 7s - loss: 1.0472 - 7s/epoch - 38ms/step
# Epoch 2/200
# 194/194 - 5s - loss: 1.0466 - 5s/epoch - 26ms/step
# Epoch 3/200
# 194/194 - 5s - loss: 1.0455 - 5s/epoch - 26ms/step
# Epoch 4/200
# 194/194 - 5s - loss: 1.0461 - 5s/epoch - 26ms/step
# Epoch 5/200
# 194/194 - 5s - loss: 1.0451 - 5s/epoch - 25ms/step
# Epoch 6/200
# 194/194 - 5s - loss: 1.0460 - 5s/epoch - 26ms/step
# Epoch 7/200
# 194/194 - 5s - loss: 1.0452 - 5s/epoch - 26ms/step
# Epoch 8/200
# 194/194 - 5s - loss: 1.0451 - 5s/epoch - 26ms/step
# Epoch 9/200
# 194/194 - 5s - loss: 1.0429 - 5s/epoch - 26ms/step
# Epoch 10/200
# 194/194 - 5s - loss: 1.0451 - 5s/epoch - 26ms/step
# Epoch 11/200
# 194/194 - 5s - loss: 1.0434 - 5s/epoch - 27ms/step
# Epoch 12/200
# 194/194 - 6s - loss: 1.0420 - 6s/epoch - 30ms/step
# Epoch 13/200
# 194/194 - 6s - loss: 1.0422 - 6s/epoch - 29ms/step
# Epoch 14/200
# 194/194 - 5s - loss: 1.0431 - 5s/epoch - 28ms/step
# Epoch 15/200
# 194/194 - 5s - loss: 1.0448 - 5s/epoch - 26ms/step
# Epoch 16/200
# 194/194 - 5s - loss: 1.0412 - 5s/epoch - 26ms/step
# Epoch 17/200
# 194/194 - 5s - loss: 1.0399 - 5s/epoch - 26ms/step
# Epoch 18/200
# 194/194 - 5s - loss: 1.0397 - 5s/epoch - 25ms/step
# Epoch 19/200
# 194/194 - 5s - loss: 1.0380 - 5s/epoch - 25ms/step
# Epoch 20/200
# 194/194 - 5s - loss: 1.0356 - 5s/epoch - 25ms/step
# Epoch 21/200
# 194/194 - 5s - loss: 1.0372 - 5s/epoch - 26ms/step
# Epoch 22/200
# 194/194 - 5s - loss: 1.0356 - 5s/epoch - 25ms/step
# Epoch 23/200
# 194/194 - 5s - loss: 1.0357 - 5s/epoch - 26ms/step
# Epoch 24/200
# 194/194 - 5s - loss: 1.0335 - 5s/epoch - 27ms/step
# Epoch 25/200
# 194/194 - 5s - loss: 1.0309 - 5s/epoch - 26ms/step
# Epoch 26/200
# 194/194 - 5s - loss: 1.0289 - 5s/epoch - 26ms/step
# Epoch 27/200
# 194/194 - 5s - loss: 1.0280 - 5s/epoch - 26ms/step
# Epoch 28/200
# 194/194 - 5s - loss: 1.0260 - 5s/epoch - 25ms/step
# Epoch 29/200
# 194/194 - 5s - loss: 1.0223 - 5s/epoch - 27ms/step
# Epoch 30/200
# 194/194 - 5s - loss: 1.0219 - 5s/epoch - 26ms/step
# Epoch 31/200
# 194/194 - 5s - loss: 1.0177 - 5s/epoch - 26ms/step
# Epoch 32/200
# 194/194 - 5s - loss: 1.0156 - 5s/epoch - 26ms/step
# Epoch 33/200
# 194/194 - 5s - loss: 1.0107 - 5s/epoch - 26ms/step
# Epoch 34/200
# 194/194 - 5s - loss: 1.0029 - 5s/epoch - 26ms/step
# Epoch 35/200
# 194/194 - 5s - loss: 1.0074 - 5s/epoch - 25ms/step
# Epoch 36/200
# 194/194 - 5s - loss: 0.9990 - 5s/epoch - 25ms/step
# Epoch 37/200
# 194/194 - 5s - loss: 0.9967 - 5s/epoch - 26ms/step
# Epoch 38/200
# 194/194 - 5s - loss: 0.9894 - 5s/epoch - 26ms/step
# Epoch 39/200
# 194/194 - 5s - loss: 0.9927 - 5s/epoch - 26ms/step
# Epoch 40/200
# 194/194 - 5s - loss: 0.9859 - 5s/epoch - 26ms/step
# Epoch 41/200
# 194/194 - 5s - loss: 0.9782 - 5s/epoch - 25ms/step
# Epoch 42/200
# 194/194 - 5s - loss: 0.9744 - 5s/epoch - 25ms/step
# Epoch 43/200
# 194/194 - 5s - loss: 0.9691 - 5s/epoch - 26ms/step
# Epoch 44/200
# 194/194 - 5s - loss: 0.9699 - 5s/epoch - 26ms/step
# Epoch 45/200
# 194/194 - 5s - loss: 0.9665 - 5s/epoch - 26ms/step
# Epoch 46/200
# 194/194 - 5s - loss: 0.9613 - 5s/epoch - 26ms/step
# Epoch 47/200
# 194/194 - 5s - loss: 0.9644 - 5s/epoch - 26ms/step
# Epoch 48/200
# 194/194 - 5s - loss: 0.9551 - 5s/epoch - 26ms/step
# Epoch 49/200
# 194/194 - 6s - loss: 0.9520 - 6s/epoch - 31ms/step
# Epoch 50/200
# 194/194 - 6s - loss: 0.9394 - 6s/epoch - 31ms/step
# Epoch 51/200
# 194/194 - 6s - loss: 0.9437 - 6s/epoch - 29ms/step
# Epoch 52/200
# 194/194 - 6s - loss: 0.9382 - 6s/epoch - 32ms/step
# Epoch 53/200
# 194/194 - 7s - loss: 0.9295 - 7s/epoch - 34ms/step
# Epoch 54/200
# 194/194 - 6s - loss: 0.9306 - 6s/epoch - 31ms/step
# Epoch 55/200
# 194/194 - 6s - loss: 0.9266 - 6s/epoch - 31ms/step
# Epoch 56/200
# 194/194 - 6s - loss: 0.9188 - 6s/epoch - 31ms/step
# Epoch 57/200
# 194/194 - 7s - loss: 0.9142 - 7s/epoch - 34ms/step
# Epoch 58/200
# 194/194 - 8s - loss: 0.9121 - 8s/epoch - 41ms/step
# Epoch 59/200
# 194/194 - 7s - loss: 0.9098 - 7s/epoch - 37ms/step
# Epoch 60/200
# 194/194 - 8s - loss: 0.9021 - 8s/epoch - 40ms/step
# Epoch 61/200
# 194/194 - 8s - loss: 0.8949 - 8s/epoch - 40ms/step
# Epoch 62/200
# 194/194 - 8s - loss: 0.8958 - 8s/epoch - 43ms/step
# Epoch 63/200
# 194/194 - 8s - loss: 0.8914 - 8s/epoch - 43ms/step
# Epoch 64/200
# 194/194 - 8s - loss: 0.8940 - 8s/epoch - 42ms/step
# Epoch 65/200
# 194/194 - 7s - loss: 0.8905 - 7s/epoch - 36ms/step
# Epoch 66/200
# 194/194 - 8s - loss: 0.8878 - 8s/epoch - 41ms/step
# Epoch 67/200
# 194/194 - 8s - loss: 0.8782 - 8s/epoch - 39ms/step
# Epoch 68/200
# 194/194 - 7s - loss: 0.8777 - 7s/epoch - 38ms/step
# Epoch 69/200
# 194/194 - 6s - loss: 0.8801 - 6s/epoch - 31ms/step
# Epoch 70/200
# 194/194 - 6s - loss: 0.8734 - 6s/epoch - 30ms/step
# Epoch 71/200
# 194/194 - 6s - loss: 0.8687 - 6s/epoch - 30ms/step
# Epoch 72/200
# 194/194 - 6s - loss: 0.8648 - 6s/epoch - 30ms/step
# Epoch 73/200
# 194/194 - 6s - loss: 0.8565 - 6s/epoch - 29ms/step
# Epoch 74/200
# 194/194 - 6s - loss: 0.8564 - 6s/epoch - 29ms/step
# Epoch 75/200
# 194/194 - 6s - loss: 0.8556 - 6s/epoch - 31ms/step
# Epoch 76/200
# 194/194 - 5s - loss: 0.8525 - 5s/epoch - 28ms/step
# Epoch 77/200
# 194/194 - 6s - loss: 0.8435 - 6s/epoch - 29ms/step
# Epoch 78/200
# 194/194 - 5s - loss: 0.8473 - 5s/epoch - 28ms/step
# Epoch 79/200
# 194/194 - 5s - loss: 0.8437 - 5s/epoch - 27ms/step
# Epoch 80/200
# 194/194 - 5s - loss: 0.8440 - 5s/epoch - 27ms/step
# Epoch 81/200
# 194/194 - 5s - loss: 0.8265 - 5s/epoch - 28ms/step
# Epoch 82/200
# 194/194 - 5s - loss: 0.8252 - 5s/epoch - 27ms/step
# Epoch 83/200
# 194/194 - 5s - loss: 0.8397 - 5s/epoch - 27ms/step
# Epoch 84/200
# 194/194 - 5s - loss: 0.8319 - 5s/epoch - 27ms/step
# Epoch 85/200
# 194/194 - 5s - loss: 0.8199 - 5s/epoch - 27ms/step
# Epoch 86/200
# 194/194 - 5s - loss: 0.8218 - 5s/epoch - 27ms/step
# Epoch 87/200
# 194/194 - 5s - loss: 0.8213 - 5s/epoch - 28ms/step
# Epoch 88/200
# 194/194 - 5s - loss: 0.8100 - 5s/epoch - 28ms/step
# Epoch 89/200
# 194/194 - 5s - loss: 0.8149 - 5s/epoch - 27ms/step
# Epoch 90/200
# 194/194 - 5s - loss: 0.8026 - 5s/epoch - 27ms/step
# Epoch 91/200
# 194/194 - 5s - loss: 0.8020 - 5s/epoch - 27ms/step
# Epoch 92/200
# 194/194 - 5s - loss: 0.8145 - 5s/epoch - 27ms/step
# Epoch 93/200
# 194/194 - 5s - loss: 0.8020 - 5s/epoch - 27ms/step
# Epoch 94/200
# 194/194 - 5s - loss: 0.7917 - 5s/epoch - 27ms/step
# Epoch 95/200
# 194/194 - 5s - loss: 0.7934 - 5s/epoch - 27ms/step
# Epoch 96/200
# 194/194 - 5s - loss: 0.7908 - 5s/epoch - 28ms/step
# Epoch 97/200
# 194/194 - 5s - loss: 0.7909 - 5s/epoch - 27ms/step
# Epoch 98/200
# 194/194 - 5s - loss: 0.7847 - 5s/epoch - 28ms/step
# Epoch 99/200
# 194/194 - 5s - loss: 0.7791 - 5s/epoch - 27ms/step
# Epoch 100/200
# 194/194 - 5s - loss: 0.7821 - 5s/epoch - 28ms/step
# Epoch 101/200
# 194/194 - 5s - loss: 0.7800 - 5s/epoch - 27ms/step
# Epoch 102/200
# 194/194 - 5s - loss: 0.7969 - 5s/epoch - 27ms/step
# Epoch 103/200
# 194/194 - 5s - loss: 0.7735 - 5s/epoch - 27ms/step
# Epoch 104/200
# 194/194 - 5s - loss: 0.7520 - 5s/epoch - 27ms/step
# Epoch 105/200
# 194/194 - 5s - loss: 0.7517 - 5s/epoch - 27ms/step
# Epoch 106/200
# 194/194 - 5s - loss: 0.7433 - 5s/epoch - 27ms/step
# Epoch 107/200
# 194/194 - 5s - loss: 0.7569 - 5s/epoch - 27ms/step
# Epoch 108/200
# 194/194 - 5s - loss: 0.7534 - 5s/epoch - 27ms/step
# Epoch 109/200
# 194/194 - 6s - loss: 0.7396 - 6s/epoch - 29ms/step
# Epoch 110/200
# 194/194 - 5s - loss: 0.7467 - 5s/epoch - 27ms/step
# Epoch 111/200
# 194/194 - 5s - loss: 0.7466 - 5s/epoch - 28ms/step
# Epoch 112/200
# 194/194 - 5s - loss: 0.7446 - 5s/epoch - 27ms/step
# Epoch 113/200
# 194/194 - 5s - loss: 0.7436 - 5s/epoch - 27ms/step
# Epoch 114/200
# 194/194 - 5s - loss: 0.7372 - 5s/epoch - 27ms/step
# Epoch 115/200
# 194/194 - 5s - loss: 0.7316 - 5s/epoch - 27ms/step
# Epoch 116/200
# 194/194 - 5s - loss: 0.7269 - 5s/epoch - 28ms/step
# Epoch 117/200
# 194/194 - 5s - loss: 0.7285 - 5s/epoch - 28ms/step
# Epoch 118/200
# 194/194 - 5s - loss: 0.7145 - 5s/epoch - 27ms/step
# Epoch 119/200
# 194/194 - 5s - loss: 0.7196 - 5s/epoch - 27ms/step
# Epoch 120/200
# 194/194 - 5s - loss: 0.7171 - 5s/epoch - 27ms/step
# Epoch 121/200
# 194/194 - 5s - loss: 0.7191 - 5s/epoch - 28ms/step
# Epoch 122/200
# 194/194 - 5s - loss: 0.7145 - 5s/epoch - 28ms/step
# Epoch 123/200
# 194/194 - 5s - loss: 0.7142 - 5s/epoch - 27ms/step
# Epoch 124/200
# 194/194 - 5s - loss: 0.7058 - 5s/epoch - 28ms/step
# Epoch 125/200
# 194/194 - 6s - loss: 0.7032 - 6s/epoch - 31ms/step
# Epoch 126/200
# 194/194 - 6s - loss: 0.6985 - 6s/epoch - 32ms/step
# Epoch 127/200
# 194/194 - 6s - loss: 0.7019 - 6s/epoch - 29ms/step
# Epoch 128/200
# 194/194 - 6s - loss: 0.6923 - 6s/epoch - 29ms/step
# Epoch 129/200
# 194/194 - 5s - loss: 0.6961 - 5s/epoch - 28ms/step
# Epoch 130/200
# 194/194 - 5s - loss: 0.6931 - 5s/epoch - 28ms/step
# Epoch 131/200
# 194/194 - 6s - loss: 0.6948 - 6s/epoch - 30ms/step
# Epoch 132/200
# 194/194 - 5s - loss: 0.6931 - 5s/epoch - 28ms/step
# Epoch 133/200
# 194/194 - 6s - loss: 0.6840 - 6s/epoch - 31ms/step
# Epoch 134/200
# 194/194 - 6s - loss: 0.6779 - 6s/epoch - 29ms/step
# Epoch 135/200
# 194/194 - 5s - loss: 0.6795 - 5s/epoch - 28ms/step
# Epoch 136/200
# 194/194 - 6s - loss: 0.6906 - 6s/epoch - 29ms/step
# Epoch 137/200
# 194/194 - 5s - loss: 0.6809 - 5s/epoch - 28ms/step
# Epoch 138/200
# 194/194 - 5s - loss: 0.6730 - 5s/epoch - 28ms/step
# Epoch 139/200
# 194/194 - 5s - loss: 0.6639 - 5s/epoch - 28ms/step
# Epoch 140/200
# 194/194 - 5s - loss: 0.6681 - 5s/epoch - 28ms/step
# Epoch 141/200
# 194/194 - 5s - loss: 0.6702 - 5s/epoch - 28ms/step
# Epoch 142/200
# 194/194 - 6s - loss: 0.6651 - 6s/epoch - 28ms/step
# Epoch 143/200
# 194/194 - 5s - loss: 0.6663 - 5s/epoch - 28ms/step
# Epoch 144/200
# 194/194 - 6s - loss: 0.6565 - 6s/epoch - 29ms/step
# Epoch 145/200
# 194/194 - 5s - loss: 0.6634 - 5s/epoch - 28ms/step
# Epoch 146/200
# 194/194 - 5s - loss: 0.6682 - 5s/epoch - 28ms/step
# Epoch 147/200
# 194/194 - 5s - loss: 0.6668 - 5s/epoch - 28ms/step
# Epoch 148/200
# 194/194 - 5s - loss: 0.6480 - 5s/epoch - 28ms/step
# Epoch 149/200
# 194/194 - 5s - loss: 0.6484 - 5s/epoch - 28ms/step
# Epoch 150/200
# 194/194 - 5s - loss: 0.6493 - 5s/epoch - 28ms/step
# Epoch 151/200
# 194/194 - 5s - loss: 0.6394 - 5s/epoch - 28ms/step
# Epoch 152/200
# 194/194 - 5s - loss: 0.6452 - 5s/epoch - 28ms/step
# Epoch 153/200
# 194/194 - 5s - loss: 0.6361 - 5s/epoch - 28ms/step
# Epoch 154/200
# 194/194 - 5s - loss: 0.6407 - 5s/epoch - 28ms/step
# Epoch 155/200
# 194/194 - 6s - loss: 0.6330 - 6s/epoch - 28ms/step
# Epoch 156/200
# 194/194 - 5s - loss: 0.6419 - 5s/epoch - 27ms/step
# Epoch 157/200
# 194/194 - 5s - loss: 0.6645 - 5s/epoch - 27ms/step
# Epoch 158/200
# 194/194 - 5s - loss: 0.6351 - 5s/epoch - 27ms/step
# Epoch 159/200
# 194/194 - 5s - loss: 0.6284 - 5s/epoch - 28ms/step
# Epoch 160/200
# 194/194 - 5s - loss: 0.6312 - 5s/epoch - 27ms/step
# Epoch 161/200
# 194/194 - 6s - loss: 0.6251 - 6s/epoch - 28ms/step
# Epoch 162/200
# 194/194 - 5s - loss: 0.6240 - 5s/epoch - 28ms/step
# Epoch 163/200
# 194/194 - 5s - loss: 0.6230 - 5s/epoch - 28ms/step
# Epoch 164/200
# 194/194 - 6s - loss: 0.6210 - 6s/epoch - 28ms/step
# Epoch 165/200
# 194/194 - 5s - loss: 0.6187 - 5s/epoch - 28ms/step
# Epoch 166/200
# 194/194 - 5s - loss: 0.6486 - 5s/epoch - 28ms/step
# Epoch 167/200
# 194/194 - 5s - loss: 0.6239 - 5s/epoch - 28ms/step
# Epoch 168/200
# 194/194 - 5s - loss: 0.6108 - 5s/epoch - 28ms/step
# Epoch 169/200
# 194/194 - 5s - loss: 0.6064 - 5s/epoch - 28ms/step
# Epoch 170/200
# 194/194 - 5s - loss: 0.6149 - 5s/epoch - 28ms/step
# Epoch 171/200
# 194/194 - 5s - loss: 0.6077 - 5s/epoch - 28ms/step
# Epoch 172/200
# 194/194 - 5s - loss: 0.6058 - 5s/epoch - 28ms/step
# Epoch 173/200
# 194/194 - 6s - loss: 0.6033 - 6s/epoch - 29ms/step
# Epoch 174/200
# 194/194 - 5s - loss: 0.6039 - 5s/epoch - 28ms/step
# Epoch 175/200
# 194/194 - 6s - loss: 0.5997 - 6s/epoch - 29ms/step
# Epoch 176/200
# 194/194 - 5s - loss: 0.5988 - 5s/epoch - 28ms/step
# Epoch 177/200
# 194/194 - 6s - loss: 0.5946 - 6s/epoch - 29ms/step
# Epoch 178/200
# 194/194 - 5s - loss: 0.5997 - 5s/epoch - 28ms/step
# Epoch 179/200
# 194/194 - 5s - loss: 0.5877 - 5s/epoch - 28ms/step
# Epoch 180/200
# 194/194 - 5s - loss: 0.5798 - 5s/epoch - 28ms/step
# Epoch 181/200
# 194/194 - 5s - loss: 0.5863 - 5s/epoch - 28ms/step
# Epoch 182/200
# 194/194 - 5s - loss: 0.5849 - 5s/epoch - 28ms/step
# Epoch 183/200
# 194/194 - 5s - loss: 0.5857 - 5s/epoch - 28ms/step
# Epoch 184/200
# 194/194 - 5s - loss: 0.5777 - 5s/epoch - 28ms/step
# Epoch 185/200
# 194/194 - 5s - loss: 0.5915 - 5s/epoch - 28ms/step
# Epoch 186/200
# 194/194 - 6s - loss: 0.5839 - 6s/epoch - 30ms/step
# Epoch 187/200
# 194/194 - 5s - loss: 0.5824 - 5s/epoch - 28ms/step
# Epoch 188/200
# 194/194 - 6s - loss: 0.5716 - 6s/epoch - 29ms/step
# Epoch 189/200
# 194/194 - 6s - loss: 0.5731 - 6s/epoch - 29ms/step
# Epoch 190/200
# 194/194 - 5s - loss: 0.5688 - 5s/epoch - 28ms/step
# Epoch 191/200
# 194/194 - 5s - loss: 0.5718 - 5s/epoch - 28ms/step
# Epoch 192/200
# 194/194 - 5s - loss: 0.5667 - 5s/epoch - 28ms/step
# Epoch 193/200
# 194/194 - 5s - loss: 0.5678 - 5s/epoch - 28ms/step
# Epoch 194/200
# 194/194 - 5s - loss: 0.5721 - 5s/epoch - 28ms/step
# Epoch 195/200
# 194/194 - 5s - loss: 0.5685 - 5s/epoch - 28ms/step
# Epoch 196/200
# 194/194 - 5s - loss: 0.5608 - 5s/epoch - 28ms/step
# Epoch 197/200
# 194/194 - 5s - loss: 0.5668 - 5s/epoch - 28ms/step
# Epoch 198/200
# 194/194 - 5s - loss: 0.5601 - 5s/epoch - 28ms/step
# Epoch 199/200
# 194/194 - 6s - loss: 0.5532 - 6s/epoch - 29ms/step
# Epoch 200/200
# 194/194 - 5s - loss: 0.5550 - 5s/epoch - 28ms/step

# %%
def predict_and_plot(model, X_train, X_test, data, scaler):
    # Perform predictions
    train_predict = model.predict(X_train)
    test_predict = model.predict(X_test)

    # Inverse transform to original scale
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)

    # Apply inverse log differencing
    last_log_train_value = data['log_close'].values[len(train_predict) - 1]
    last_log_test_value = data['log_close'].values[-len(test_predict) - 1]
    train_predict = np.exp(last_log_train_value + train_predict[:,0])
    test_predict = np.exp(last_log_test_value + test_predict[:,0])


    # Calculate RMSE for test data
    test_rmse = sqrt(mean_squared_error(data['Close'].values[-len(test_predict):], test_predict))
    print('Test RMSE:', test_rmse)

    # Plot the results
    plt.figure(figsize=(12, 6))
    plt.plot(data['Close'].values, label='Original Close Prices')
    plt.plot(np.arange(len(train_predict)), data['Close'].values[:len(train_predict)], label='Training Data')
    plt.plot(np.arange(len(train_predict), len(train_predict) + len(test_predict)), test_predict, label='Testing Predictions')
    plt.title('Stock Price Prediction using Log Differenced Residuals with LSTM')
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()

# %%
predict_and_plot(model, X_train, X_test, data, scaler)
# Out:
# 2023-11-20 15:12:55.245547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-20 15:12:55.247949: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-20 15:12:55.248743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-11-20 15:12:55.357502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-20 15:12:55.358186: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-20 15:12:55.358894: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 388/388 [==============================] - 3s 7ms/step
# 96/96 [==============================] - 1s 7ms/step
# Test RMSE: 25.144386081100677
